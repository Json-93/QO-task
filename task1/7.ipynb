# %%
# What are the similarities and diﬀerences between your Cat and Kitten states?
# 相同：都有雙峰，也有向下凹陷的部分
# 相異：雙峰之間部分，Cat有其他波峰，而 Kitten 原則上沒有

# Similarities:
# Structure: Both are quantum superpositions of coherent states used for quantum sensing, computing, and communication.
# Generation: Both can be generated using similar methods, such as utilizing a single trapped ion in a Paul trap, and share similar coherence properties.
# Superposition: Both represent non-classical superposition states. 

# Differences:
# Scale/Separation: Cat states involve superpositions of macroscopically distinguishable states (e.g., |𝛼⟩ and |−𝛼⟩ where α is large), while kitten states are only slightly different.
# Amplitude: Kitten states typically involve small amplitudes (𝛼 ≤ 2), whereas cat states imply larger, more distinct amplitudes.
# Parity: "Hot" cat states (a type of cat state) can have different, often lower, parity compared to other superpositions like hot qcMAP states, although they can still share similar coherence functions.
# Macroscopic distinction: The fundamental defining difference is that cat states are macroscopically distinct ("alive and dead"), while kitten states are not. 

# Essentially, kitten states are a smaller, less "distinct" version of a Schrodinger cat state, often used as an intermediate step or in situations where high-amplitude separation is not yet required.
# Out:
#   Cell In[1], line 2
#     相同：都有雙峰，也有向下凹陷的部分
#       ^
# SyntaxError: invalid character '：' (U+FF1A)
