# %%
# Similarities：
#     1. Wigner function 都出現負值區域
#     2. phase space 都跑出干涉條紋
#     3. Hamiltonian H = ℏω(â† * â + 1/2) 下，兩者都在 phase space 旋轉
#
# Differences：
#     1. Cat state 是兩個相干態的線性疊加，|Cat⟩ = |α⟩ − |−α⟩； Kitten state 是對 vaccum state 作用， |Kitten⟩ = â†|ξ⟩。
#     2. Wigner function：Cat state 有兩個對稱分離的峰加上中央干涉條紋； Kitten state 受壓縮方向影響。
#     3. Fidelity ＝ 0.1604
